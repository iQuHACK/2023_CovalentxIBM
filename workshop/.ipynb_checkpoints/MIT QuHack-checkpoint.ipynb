# %% [markdown]
# # Covalent QuHack Workshop
#
#
# The goal of this workshop is to showcase how one can install & set up covalent as well as how to use the plugin ecosystem to interact with cloud compute resources. We will run through several examples of workflows using covalent locally, a remote deployment of covalent on AWS, and workflows that utilize AWS plugins. Lastly we will cover an example using Qiskit & Pennylane with Covalent to evaluate Quantum Circuits.
#
# The structure is as follows:
# 1. How to use covalent locally
# 2. How to use AWS executor plugins
# 3. Host covalent on AWS
# 4. Use executor plugins on hosted covalent
# 5. Example workflow using Qiskit & Pennylane
#
#
# Some useful links include:
# - https://github.com/AgnostiqHQ/covalent Covalent Github Repo
# - https://covalent.readthedocs.io/en/latest/getting_started/quick_start/index.html Getting Started Guide

# %% [markdown]
# ## Getting Started with Covalent
#
# To install covalent install it with pip:

# %%
# %pip install covalent --no-cache
# Out:
# Requirement already satisfied: covalent in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (0.209.1)
# Requirement already satisfied: requests<=2.28.1,>=2.24.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from covalent) (2.28.1)
# Requirement already satisfied: aiohttp==3.8.1 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from covalent) (3.8.1)
# Requirement already satisfied: toml==0.10.2 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from covalent) (0.10.2)
# Requirement already satisfied: networkx==2.8.6 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from covalent) (2.8.6)
# Requirement already satisfied: uvicorn[standard]<=0.18.3,>=0.18.2 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from covalent) (0.18.3)
# Requirement already satisfied: furl==2.1.3 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from covalent) (2.1.3)
# Requirement already satisfied: dask[distributed]<=2022.9.0,>=2022.6.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from covalent) (2022.9.0)
# Requirement already satisfied: psutil<=5.9.2,>=5.9.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from covalent) (5.9.2)
# Requirement already satisfied: sqlalchemy-utils==0.38.3 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from covalent) (0.38.3)
# Requirement already satisfied: pydantic<=1.10.2,>=1.10.1 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from covalent) (1.10.2)
# Requirement already satisfied: python-socketio==5.7.1 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from covalent) (5.7.1)
# Requirement already satisfied: aiofiles<=22.1.0,>=0.8.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from covalent) (22.1.0)
# Requirement already satisfied: click==8.1.3 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from covalent) (8.1.3)
# Requirement already satisfied: sqlalchemy<=1.4.41,>=1.4.37 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from covalent) (1.4.41)
# Requirement already satisfied: simplejson==3.17.6 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from covalent) (3.17.6)
# Requirement already satisfied: werkzeug<=2.2.2,>=2.0.3 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from covalent) (2.2.2)
# Requirement already satisfied: alembic<=1.8.1,>=1.8.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from covalent) (1.8.1)
# Requirement already satisfied: fastapi<=0.83.0,>=0.79.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from covalent) (0.83.0)
# Requirement already satisfied: cloudpickle<=2.2.0,>=2.0.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from covalent) (2.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from aiohttp==3.8.1->covalent) (6.0.4)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from aiohttp==3.8.1->covalent) (2.1.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from aiohttp==3.8.1->covalent) (1.8.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from aiohttp==3.8.1->covalent) (22.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from aiohttp==3.8.1->covalent) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from aiohttp==3.8.1->covalent) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from aiohttp==3.8.1->covalent) (4.0.2)
# Requirement already satisfied: orderedmultidict>=1.0.1 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from furl==2.1.3->covalent) (1.0.1)
# Requirement already satisfied: six>=1.8.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from furl==2.1.3->covalent) (1.16.0)
# Requirement already satisfied: python-engineio>=4.3.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from python-socketio==5.7.1->covalent) (4.3.4)
# Requirement already satisfied: bidict>=0.21.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from python-socketio==5.7.1->covalent) (0.22.1)
# Requirement already satisfied: importlib-resources in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from alembic<=1.8.1,>=1.8.0->covalent) (5.10.2)
# Requirement already satisfied: importlib-metadata in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from alembic<=1.8.1,>=1.8.0->covalent) (6.0.0)
# Requirement already satisfied: Mako in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from alembic<=1.8.1,>=1.8.0->covalent) (1.2.4)
# Requirement already satisfied: toolz>=0.8.2 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from dask[distributed]<=2022.9.0,>=2022.6.0->covalent) (0.12.0)
# Requirement already satisfied: partd>=0.3.10 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from dask[distributed]<=2022.9.0,>=2022.6.0->covalent) (1.3.0)
# Requirement already satisfied: fsspec>=0.6.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from dask[distributed]<=2022.9.0,>=2022.6.0->covalent) (2023.1.0)
# Requirement already satisfied: packaging>=20.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from dask[distributed]<=2022.9.0,>=2022.6.0->covalent) (23.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from dask[distributed]<=2022.9.0,>=2022.6.0->covalent) (6.0)
# Requirement already satisfied: distributed==2022.9.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from dask[distributed]<=2022.9.0,>=2022.6.0->covalent) (2022.9.0)
# Requirement already satisfied: jinja2 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from distributed==2022.9.0->dask[distributed]<=2022.9.0,>=2022.6.0->covalent) (3.1.2)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from distributed==2022.9.0->dask[distributed]<=2022.9.0,>=2022.6.0->covalent) (2.4.0)
# Requirement already satisfied: msgpack>=0.6.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from distributed==2022.9.0->dask[distributed]<=2022.9.0,>=2022.6.0->covalent) (1.0.4)
# Requirement already satisfied: zict>=0.1.3 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from distributed==2022.9.0->dask[distributed]<=2022.9.0,>=2022.6.0->covalent) (2.2.0)
# Collecting tornado<6.2,>=6.0.3
#   Downloading tornado-6.1-cp38-cp38-manylinux2010_x86_64.whl (427 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.5/427.5 kB 2.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: urllib3 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from distributed==2022.9.0->dask[distributed]<=2022.9.0,>=2022.6.0->covalent) (1.26.14)
# Requirement already satisfied: locket>=1.0.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from distributed==2022.9.0->dask[distributed]<=2022.9.0,>=2022.6.0->covalent) (1.0.0)
# Requirement already satisfied: tblib>=1.6.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from distributed==2022.9.0->dask[distributed]<=2022.9.0,>=2022.6.0->covalent) (1.7.0)
# Requirement already satisfied: starlette==0.19.1 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from fastapi<=0.83.0,>=0.79.0->covalent) (0.19.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from starlette==0.19.1->fastapi<=0.83.0,>=0.79.0->covalent) (3.6.2)
# Requirement already satisfied: typing-extensions>=3.10.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from starlette==0.19.1->fastapi<=0.83.0,>=0.79.0->covalent) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from requests<=2.28.1,>=2.24.0->covalent) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from requests<=2.28.1,>=2.24.0->covalent) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from sqlalchemy<=1.4.41,>=1.4.37->covalent) (2.0.2)
# Requirement already satisfied: h11>=0.8 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from uvicorn[standard]<=0.18.3,>=0.18.2->covalent) (0.14.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from uvicorn[standard]<=0.18.3,>=0.18.2->covalent) (0.17.0)
# Requirement already satisfied: python-dotenv>=0.13 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from uvicorn[standard]<=0.18.3,>=0.18.2->covalent) (0.21.1)
# Requirement already satisfied: websockets>=10.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from uvicorn[standard]<=0.18.3,>=0.18.2->covalent) (10.4)
# Requirement already satisfied: httptools>=0.4.0 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from uvicorn[standard]<=0.18.3,>=0.18.2->covalent) (0.5.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from uvicorn[standard]<=0.18.3,>=0.18.2->covalent) (0.18.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from werkzeug<=2.2.2,>=2.0.3->covalent) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from importlib-metadata->alembic<=1.8.1,>=1.8.0->covalent) (3.12.0)
# Requirement already satisfied: sniffio>=1.1 in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from anyio<5,>=3.4.0->starlette==0.19.1->fastapi<=0.83.0,>=0.79.0->covalent) (1.3.0)
# Requirement already satisfied: heapdict in /home/kapow_12/2023_CovalentxIBM/venv/lib/python3.8/site-packages (from zict>=0.1.3->distributed==2022.9.0->dask[distributed]<=2022.9.0,>=2022.6.0->covalent) (1.0.1)
# Installing collected packages: tornado
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.2
#     Uninstalling tornado-6.2:
#       Successfully uninstalled tornado-6.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-server 2.1.0 requires tornado>=6.2.0, but you have tornado 6.1 which is incompatible.
# jupyter-client 8.0.1 requires tornado>=6.2, but you have tornado 6.1 which is incompatible.
# Successfully installed tornado-6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install tornado
# Out:
# Collecting tornado
#   Using cached tornado-6.2-cp37-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (423 kB)
# Installing collected packages: tornado
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# distributed 2022.9.0 requires tornado<6.2,>=6.0.3, but you have tornado 6.2 which is incompatible.
# Successfully installed tornado-6.2

# %% [markdown]
# To start covalent run the following in your terminal:
#
# **$ covalent start**
#
# > Note: This may not work if run in the notebook so be sure to use your shell in the same virtualenv as your notebook.

# %%
# Say we have a simple script as follows
def add(x, y):
   return x + y

def multiply(x, y):
   return x*y

def divide(x, y):
   return x/y

def workflow(x, y):
   r1 = add(x, y)
   r2 = [multiply(r1, y) for _ in range(4)]
   r3 = [divide(x, value) for value in r2]
   return r1,r2,r3

print(workflow(1,2))

# %%
# With no code changes we add decorators to covert to a covalent workflow

import covalent as ct

@ct.electron
def add(x, y):
   return x + y

@ct.electron
def multiply(x, y):
   return x*y

@ct.electron
def divide(x, y):
   return x/y

@ct.lattice
def workflow(x, y):
   r1 = add(x, y)
   r2 = [multiply(r1, y) for _ in range(4)]
   r3 = [divide(x, value) for value in r2]
   return r1,r2,r3

# %%
dispatch_id = ct.dispatch(workflow)(1, 2)
result = ct.get_result(dispatch_id, wait=True)
print(result.result)

# %% [markdown]
# ##  AWS Account Setup
#
# In order to interact with AWS services from your machine you must:
#
# 1. Have an AWS Account (Free): https://aws.amazon.com/free/
# 2. Install the AWS CLI: https://docs.aws.amazon.com/cli/latest/userguide/getting-started-install.html
#
# Furthermore, if you don't already have one you will need to create an account. Once you are logged in you will want to go to IAM and then to Manage Security Credentials to obtain an `aws_access_key_id` and `aws_secret_access_key`. At which point you will need to store your credentials locally by using the cli:
#
# ```bash
# $ aws configure
# ```
#
# Alternatively you can go to `~/.aws/credentials` and create a section:
#
# ```
# [default]
# aws_access_key_id=<ACCESS_KEY>
# aws_secret_access_key=<SECRET_ACCESS_KEY>
# ```
#
# ## Using AWS Executor Plugins in Covalent (AWS Batch)
#
# It is recommended to read our documentation of [AWS Executor Plugins](https://covalent.readthedocs.io/en/latest/api/executors/awsplugins.html)
#
# ### We will now show a toy example of training an SVM ML model using a covalent workflow (without executors)

# %%
# %pip install numpy==1.23.2 scikit-learn==1.1.2

# %%
# Train SVM w/out Executor

from numpy.random import permutation
from sklearn import svm, datasets
import covalent as ct

@ct.electron
def train_svm(data, C, gamma):
    X, y = data
    clf = svm.SVC(C=C, gamma=gamma)
    clf.fit(X[90:], y[90:])
    return clf

@ct.electron
def load_data():
    iris = datasets.load_iris()
    perm = permutation(iris.target.size)
    iris.data = iris.data[perm]
    iris.target = iris.target[perm]
    return iris.data, iris.target

@ct.electron
def score_svm(data, clf):
    X_test, y_test = data
    return clf.score(
      X_test[:90],
    y_test[:90]
    )

@ct.lattice
def run_experiment(C=1.0, gamma=0.7):
    data = load_data()
    clf = train_svm(
      data=data,
      C=C,
      gamma=gamma
    )
    score = score_svm(
      data=data,
    clf=clf
    )
    return score

# Dispatch the workflow
dispatch_id = ct.dispatch(run_experiment)(
  C=1.0,
  gamma=0.7
)

# Wait for our result and get result value
result = ct.get_result(dispatch_id=dispatch_id, wait=True).result

# Get Mean Accuracy of our model
print(result)

# %% [markdown]
# ### We will now use the AWS Batch executor plugin

# %%
# %pip install covalent-awsbatch-plugin --no-cache # Note: we need to restart covalent after installing plugins

# %%
# Import Executor (AWS Batch)

import covalent as ct
from covalent.executor import AWSBatchExecutor

deps_pip = ct.DepsPip(
  packages=["numpy==1.23.2", "scikit-learn==1.1.2"]
)

executor = AWSBatchExecutor(
    region='us-east-1',
    s3_bucket_name='<s3_bucket_name>',
    batch_queue='<batch_queue>',
    batch_job_role_name='<batch_job_role_name>',
    batch_job_log_group_name='<batch_job_log_group_name>',
    batch_execution_role_name='<batch_execution_role_name>',
    vcpu=2,
    memory=3.75,
    time_limit=300
)

# %% [markdown]
# To use any executor plugins we add the `executor` key to the `@electron` decorator, for example:
#
# ```python
# @ct.electron(
#     executor=executor
# )
# def train_svm(data, C, gamma):
#     X, y = data
#     clf = svm.SVC(C=C, gamma=gamma)
#     clf.fit(X[90:], y[90:])
#     return clf
# ```

# %%
# Use executor plugin to train our SVM model.
from numpy.random import permutation
from sklearn import svm, datasets
import covalent as ct

@ct.electron(
    executor=executor,
    deps_pip=deps_pip
)
def train_svm(data, C, gamma):
    X, y = data
    clf = svm.SVC(C=C, gamma=gamma)
    clf.fit(X[90:], y[90:])
    return clf

@ct.electron
def load_data():
    iris = datasets.load_iris()
    perm = permutation(iris.target.size)
    iris.data = iris.data[perm]
    iris.target = iris.target[perm]
    return iris.data, iris.target

@ct.electron
def score_svm(data, clf):
    X_test, y_test = data
    return clf.score(
      X_test[:90],
    y_test[:90]
    )

@ct.lattice
def run_experiment(C=1.0, gamma=0.7):
    data = load_data()
    clf = train_svm(
      data=data,
      C=C,
      gamma=gamma
    )
    score = score_svm(
      data=data,
    clf=clf
    )
    return score

# Dispatch the workflow
dispatch_id = ct.dispatch(run_experiment)(
  C=1.0,
  gamma=0.7
)

# Wait for our result and get result value
result = ct.get_result(dispatch_id=dispatch_id, wait=True).result

print(result)

# %% [markdown]
# ## Using Self Hosted Version of Covalent
#
# In order to deploy the self-hosted instance of covalent we will require Terraform in order to programatically create AWS Resources such as VMs (EC2) instances, and other resources required for using the AWS Executors.
#
# The installation guide for Terraform is the following:
# - https://developer.hashicorp.com/terraform/tutorials/aws-get-started/install-cli#install-terraform
#
# We will now run through an example deployment of Covalent to AWS, the following repository contains all of the instructions for going about this:
# - https://github.com/AgnostiqHQ/covalent-terraform

# %%
import covalent as ct

ct.set_config("dispatcher.address", "<URL_FROM_TERRAFORM>")
ct.set_config("dispatcher.port", "48008")

# %% [markdown]
# ### Important! Since now covalent is now running remotely we will need to install all dependencies required for each task
#
# ```python
# @ct.electron(deps_pip=ct.DepsPip(packages=["numpy==1.23.2"]))
# def my_task():
#     return np.random.rand(3,2)
# ```
#
# ### Furthermore, executor plugins on remote covalent are pre-configured so they can be referred to simply as:
#
# ```python
# @ct.electron(executor="awsbatch")
# def my_batch_task():
#     pass
# ```
#
# The following are supported executors on hosted covalent:
#
# - AWS Batch used as `"awsbatch"`
# - AWS Lambda used as `"awslambda"`
# - AWS Braket used as `"braket"`
#
# #### To use Amazon Braket in a new account you must visit
# - https://console.aws.amazon.com/braket/home?#/permissions?tab=executionRoles
# To create a service-linked role

# %%
# Import Executor (AWS Batch) - Note: we are using aliased executors

import covalent as ct
from covalent.executor import AWSBatchExecutor

deps_pip = ct.DepsPip(
  packages=["numpy==1.23.2", "scikit-learn==1.1.2"]
)

# As before we use the executor and install dependencies
@ct.electron(
    executor="awsbatch",
    deps_pip=deps_pip
)
def train_svm(data, C, gamma):
    X, y = data
    clf = svm.SVC(C=C, gamma=gamma)
    clf.fit(X[90:], y[90:])
    return clf

# IMPORTANT now since covalent is running remotely we must install the dependencies each task.
@ct.electron(
    deps_pip=deps_pip
)
def load_data():
    iris = datasets.load_iris()
    perm = permutation(iris.target.size)
    iris.data = iris.data[perm]
    iris.target = iris.target[perm]
    return iris.data, iris.target

@ct.electron(
    deps_pip=deps_pip
)
def score_svm(data, clf):
    X_test, y_test = data
    return clf.score(
      X_test[:90],
    y_test[:90]
    )

@ct.lattice
def run_experiment(C=1.0, gamma=0.7):
    data = load_data()
    clf = train_svm(
      data=data,
      C=C,
      gamma=gamma
    )
    score = score_svm(
      data=data,
    clf=clf
    )
    return score

# Dispatch the workflow
dispatch_id = ct.dispatch(run_experiment)(
  C=1.0,
  gamma=0.7
)

# Wait for our result and get result value
result = ct.get_result(dispatch_id=dispatch_id, wait=True).result

print(result)

# %% [markdown]
# ### To revert to local covalent you can use the following

# %%
import covalent as ct

ct.set_config("dispatcher.address", "localhost")
ct.set_config("dispatcher.port", "48008")

# %% [markdown]
# ## Quiskit & Pennylane Quantum Circuit Example

# %% [markdown]
# Install qiskit & pennylane as well as the pennylane braket plugin:

# %%
# %pip remove qiskit pennylane amazon-braket-pennylane-plugin
# Out:
# Collecting qiskit
#   Downloading qiskit-0.40.0.tar.gz (14 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pennylane
#   Downloading PennyLane-0.28.0-py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 6.3 MB/s eta 0:00:00
# Collecting amazon-braket-pennylane-plugin
#   Downloading amazon_braket_pennylane_plugin-1.10.4-py3-none-any.whl (23 kB)
# Collecting qiskit-terra==0.23.0
#   Downloading qiskit_terra-0.23.0-cp310-cp310-win_amd64.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 7.8 MB/s eta 0:00:00
# Collecting qiskit-aer==0.11.2
#   Downloading qiskit_aer-0.11.2-cp310-cp310-win_amd64.whl (9.6 MB)
#      ---------------------------------------- 9.6/9.6 MB 6.5 MB/s eta 0:00:00
# Collecting qiskit-ibmq-provider==0.19.2
#   Downloading qiskit_ibmq_provider-0.19.2-py3-none-any.whl (240 kB)
#      -------------------------------------- 240.4/240.4 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.3 in c:\tools\manim\lib\site-packages (from qiskit-aer==0.11.2->qiskit) (1.23.5)
# Requirement already satisfied: scipy>=1.0 in c:\tools\manim\lib\site-packages (from qiskit-aer==0.11.2->qiskit) (1.9.3)
# Requirement already satisfied: urllib3>=1.21.1 in c:\tools\manim\lib\site-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (1.26.13)
# Collecting requests-ntlm>=1.1.0
#   Downloading requests_ntlm-1.1.0-py2.py3-none-any.whl (5.7 kB)
# Requirement already satisfied: websocket-client>=1.0.1 in c:\users\kapow\appdata\local\programs\python\python310\lib\site-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (1.5.0)
# Requirement already satisfied: requests>=2.19 in c:\tools\manim\lib\site-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (2.28.1)
# Collecting websockets>=10.0
#   Downloading websockets-10.4-cp310-cp310-win_amd64.whl (101 kB)
#      -------------------------------------- 101.4/101.4 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\kapow\appdata\local\programs\python\python310\lib\site-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (2.8.2)
# Requirement already satisfied: psutil>=5 in c:\users\kapow\appdata\local\programs\python\python310\lib\site-packages (from qiskit-terra==0.23.0->qiskit) (5.9.4)
# Collecting ply>=3.10
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ---------------------------------------- 49.6/49.6 kB 2.6 MB/s eta 0:00:00
# Collecting stevedore>=3.0.0
#   Downloading stevedore-4.1.1-py3-none-any.whl (50 kB)
#      ---------------------------------------- 50.0/50.0 kB ? eta 0:00:00
# Collecting dill>=0.3
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      -------------------------------------- 110.5/110.5 kB 6.3 MB/s eta 0:00:00
# Collecting sympy>=1.3
#   Using cached sympy-1.11.1-py3-none-any.whl (6.5 MB)
# Collecting rustworkx>=0.12.0
#   Downloading rustworkx-0.12.1-cp310-cp310-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 5.8 MB/s eta 0:00:00
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: networkx in c:\tools\manim\lib\site-packages (from pennylane) (2.8.8)
# Collecting retworkx
#   Downloading retworkx-0.12.1-py3-none-any.whl (10 kB)
# Collecting appdirs
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting autoray>=0.3.1
#   Downloading autoray-0.6.0-py3-none-any.whl (46 kB)
#      ---------------------------------------- 46.4/46.4 kB 2.3 MB/s eta 0:00:00
# Collecting semantic-version>=2.7
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting autograd
#   Downloading autograd-1.5-py3-none-any.whl (48 kB)
#      ---------------------------------------- 48.9/48.9 kB 2.4 MB/s eta 0:00:00
# Collecting cachetools
#   Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting pennylane-lightning>=0.28
#   Downloading PennyLane_Lightning-0.28.2-cp310-cp310-win_amd64.whl (4.5 MB)
#      ---------------------------------------- 4.5/4.5 MB 7.3 MB/s eta 0:00:00
# Collecting pennylane
#   Downloading PennyLane-0.27.0-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 4.8 MB/s eta 0:00:00
# Collecting amazon-braket-sdk>=1.35.0
#   Downloading amazon_braket_sdk-1.35.3-py3-none-any.whl (245 kB)
#      -------------------------------------- 245.8/245.8 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio in c:\users\kapow\appdata\local\programs\python\python310\lib\site-packages (from amazon-braket-sdk>=1.35.0->amazon-braket-pennylane-plugin) (1.5.6)
# Collecting openqasm3
#   Downloading openqasm3-0.4.0-py3-none-any.whl (385 kB)
#      -------------------------------------- 385.3/385.3 kB 6.0 MB/s eta 0:00:00
# Collecting boltons
#   Downloading boltons-21.0.0-py2.py3-none-any.whl (193 kB)
#      ------------------------------------- 193.7/193.7 kB 12.2 MB/s eta 0:00:00
# Collecting oqpy~=0.1.1
#   Downloading oqpy-0.1.2-py3-none-any.whl (27 kB)
# Collecting openpulse
#   Downloading openpulse-0.4.1-py3-none-any.whl (376 kB)
#      -------------------------------------- 376.3/376.3 kB 5.8 MB/s eta 0:00:00
# Collecting backoff
#   Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting boto3>=1.22.3
#   Downloading boto3-1.26.59-py3-none-any.whl (132 kB)
#      -------------------------------------- 132.7/132.7 kB 7.7 MB/s eta 0:00:00
# Collecting amazon-braket-default-simulator>=1.11.0
#   Downloading amazon_braket_default_simulator-1.11.4-py3-none-any.whl (206 kB)
#      -------------------------------------- 206.7/206.7 kB 4.2 MB/s eta 0:00:00
# Collecting amazon-braket-schemas>=1.14.0
#   Downloading amazon_braket_schemas-1.14.0-py3-none-any.whl (109 kB)
#      -------------------------------------- 109.9/109.9 kB 6.2 MB/s eta 0:00:00
# Collecting pennylane-lightning>=0.28
#   Downloading PennyLane_Lightning-0.28.1-cp310-cp310-win_amd64.whl (4.5 MB)
#      ---------------------------------------- 4.5/4.5 MB 6.5 MB/s eta 0:00:00
#   Downloading PennyLane_Lightning-0.28.0-cp310-cp310-win_amd64.whl (4.5 MB)
#      ---------------------------------------- 4.5/4.5 MB 6.5 MB/s eta 0:00:00
# Collecting ninja
#   Downloading ninja-1.11.1-py2.py3-none-win_amd64.whl (313 kB)
#      -------------------------------------- 313.0/313.0 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in c:\tools\manim\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\tools\manim\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\tools\manim\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit) (2022.12.7)
# Collecting future>=0.15.2
#   Downloading future-0.18.3.tar.gz (840 kB)
#      -------------------------------------- 840.9/840.9 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting opt-einsum
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ---------------------------------------- 65.5/65.5 kB 3.5 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime==4.9.2
#   Downloading antlr4-python3-runtime-4.9.2.tar.gz (117 kB)
#      -------------------------------------- 117.2/117.2 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pydantic<2.0,>=1.9
#   Downloading pydantic-1.10.4-cp310-cp310-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 6.0 MB/s eta 0:00:00
# Collecting botocore<1.30.0,>=1.29.59
#   Downloading botocore-1.29.59-py3-none-any.whl (10.4 MB)
#      ---------------------------------------- 10.4/10.4 MB 6.1 MB/s eta 0:00:00
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ---------------------------------------- 79.6/79.6 kB 4.3 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting mypy-extensions>=0.2.0
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Requirement already satisfied: six>=1.5 in c:\tools\manim\lib\site-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider==0.19.2->qiskit) (1.16.0)
# Collecting cryptography>=1.3
#   Downloading cryptography-39.0.0-cp36-abi3-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 6.5 MB/s eta 0:00:00
# Collecting ntlm-auth>=1.0.2
#   Downloading ntlm_auth-1.5.0-py2.py3-none-any.whl (29 kB)
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.11.1-py2.py3-none-any.whl (112 kB)
#      -------------------------------------- 112.7/112.7 kB 3.3 MB/s eta 0:00:00
# Collecting mpmath>=0.19
#   Using cached mpmath-1.2.1-py3-none-any.whl (532 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\kapow\appdata\local\programs\python\python310\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit) (1.15.1)
# Collecting typing-extensions>=4.2.0
#   Using cached typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: pycparser in c:\users\kapow\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit) (2.21)
# Building wheels for collected packages: qiskit, antlr4-python3-runtime, future
#   Building wheel for qiskit (setup.py): started
#   Building wheel for qiskit (setup.py): finished with status 'done'
#   Created wheel for qiskit: filename=qiskit-0.40.0-py3-none-any.whl size=12857 sha256=a7cd975dca220d9b43918ac6ef3b630029a0036e4f6766d2db4dabb2e89b861d
#   Stored in directory: c:\users\kapow\appdata\local\pip\cache\wheels\c5\00\ef\b840aa2b1f36f5d392fc563ce3c992fb54d1a4d6ea0c29dc00
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.2-py3-none-any.whl size=144570 sha256=433e9964fe8972ff87429cefd62c42053c146d84092fe8e480968202f512a072
#   Stored in directory: c:\users\kapow\appdata\local\pip\cache\wheels\cb\fe\63\a55475ac3f45871d57cb15ce76753c7f261563256f7bacf3a9
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.3-py3-none-any.whl size=492055 sha256=7e944f70456c39f5b719448f81603b0757ecfaa185fc14e63c71afb676ef1e93
#   Stored in directory: c:\users\kapow\appdata\local\pip\cache\wheels\69\c0\ce\f2a18105d619f21239a048bcc58e98d8ce47ac824e0531f1a0
# Successfully built qiskit antlr4-python3-runtime future
# Installing collected packages: ply, openqasm3, ninja, mypy-extensions, mpmath, boltons, appdirs, antlr4-python3-runtime, websockets, typing-extensions, toml, sympy, semantic-version, rustworkx, pbr, opt-einsum, ntlm-auth, jmespath, future, dill, cachetools, backoff, autoray, stevedore, retworkx, pydantic, openpulse, cryptography, botocore, autograd, s3transfer, requests-ntlm, qiskit-terra, oqpy, amazon-braket-schemas, qiskit-ibmq-provider, qiskit-aer, boto3, amazon-braket-default-simulator, qiskit, amazon-braket-sdk, pennylane-lightning, pennylane, amazon-braket-pennylane-plugin
# Successfully installed amazon-braket-default-simulator-1.11.4 amazon-braket-pennylane-plugin-1.10.4 amazon-braket-schemas-1.14.0 amazon-braket-sdk-1.35.3 antlr4-python3-runtime-4.9.2 appdirs-1.4.4 autograd-1.5 autoray-0.6.0 backoff-2.2.1 boltons-21.0.0 boto3-1.26.59 botocore-1.29.59 cachetools-5.3.0 cryptography-39.0.0 dill-0.3.6 future-0.18.3 jmespath-1.0.1 mpmath-1.2.1 mypy-extensions-0.4.3 ninja-1.11.1 ntlm-auth-1.5.0 openpulse-0.4.1 openqasm3-0.4.0 opt-einsum-3.3.0 oqpy-0.1.2 pbr-5.11.1 pennylane-0.27.0 pennylane-lightning-0.28.0 ply-3.11 pydantic-1.10.4 qiskit-0.40.0 qiskit-aer-0.11.2 qiskit-ibmq-provider-0.19.2 qiskit-terra-0.23.0 requests-ntlm-1.1.0 retworkx-0.12.1 rustworkx-0.12.1 s3transfer-0.6.0 semantic-version-2.10.0 stevedore-4.1.1 sympy-1.11.1 toml-0.10.2 typing-extensions-4.4.0 websockets-10.4
# Note: you may need to restart the kernel to use updated packages.

# %%
"""
Compare expectation value estimates for 'M = I ⊗ Z' on the final state of the circuit,
     ┌────┐
q_0: ┤ Rz ├──■────────
     └────┘┌─┴─┐┌────┐
q_1: ──────┤ X ├┤ Ry ├
           └───┘└────┘
for arbitrary Z- and Y-rotation angles, as implemented in qiskit versus pennylane.
"""
from math import pi as PI
from typing import List, Tuple

import covalent as ct
import pennylane as qml
from qiskit import Aer, QuantumCircuit
from qiskit.opflow import CircuitStateFn, I, Z
from qiskit.opflow.state_fns import StateFn
from qiskit.opflow.expectations import PauliExpectation
from qiskit.opflow.converters import CircuitSampler

SHOTS = 10_000

# use the local braket backend for pennylane
QML_BRAKET_DEVICE = qml.device("braket.local.qubit", wires=2, shots=SHOTS)

# NOTE: use the Aer simulator instead of Quantinuum backend for now
QISKIT_BACKEND = Aer.get_backend("aer_simulator_statevector", shots=SHOTS)



@ct.electron(deps_pip=ct.DepsPip(packages=["qiskit"]))
def get_expval_from_qiskit(phi_z: float, phi_y: float) -> float:
    """qiskit implementation of the simulation"""
    qiskit_circuit = QuantumCircuit(2)
    qiskit_circuit.rz(phi_z, 0)
    qiskit_circuit.cnot(0, 1)
    qiskit_circuit.ry(phi_y, 1)

    psi = CircuitStateFn(qiskit_circuit)
    op = Z ^ I
    measureable_expr = StateFn(op, is_measurement=True).compose(psi)
    expectation = PauliExpectation().convert(measureable_expr)
    sampler = CircuitSampler(QISKIT_BACKEND).convert(expectation)
    return sampler.eval().real


@ct.electron(deps_pip=ct.DepsPip(packages=["pennylane"]))
def get_expval_from_pennylane(phi_z: float, phi_y: float) -> float:
    """pennylane implementation of the simulation"""
    @qml.qnode(device=QML_BRAKET_DEVICE)
    def _circuit():
        qml.RZ(phi_z, wires=0)
        qml.CNOT(wires=[0, 1])
        qml.RY(phi_y, wires=1)
        return qml.expval(qml.PauliZ(1))

    return float(_circuit())

@ct.electron
def mse(expvals_1: List[float], expvals_2: List[float]) -> float:
    """calculates MSE between two lists of floats"""
    assert len(expvals_1) == len(expvals_2)
    squared_error_sum = 0.0
    for e1, e2 in zip(expvals_1, expvals_2):
        squared_error_sum += (e1 - e2)**2
    return squared_error_sum / len(expvals_1)


@ct.lattice
def sweep_angles(angles: List[Tuple[float, float]]) -> float:
    """
    Get exp. values from qiskit and pennylane functions implementing the same
    quantum circuit and compare the outputs based on MSE

    Parameters
    ----------
    angles : List[Tuple[float, float]]
        pairs of angle parameters (phi_z, phi_y) for the quantum circuit

    Returns
    -------
    float
        mean squared error between qiskit and pennylane circuit results (should be ~0)
    """
    expvals_qiskit = []
    expvals_pennylane = []
    for phi_z, phi_y in angles:
        expvals_qiskit.append(get_expval_from_qiskit(phi_z, phi_y))
        expvals_pennylane.append(get_expval_from_pennylane(phi_z, phi_y))

    return mse(expvals_qiskit, expvals_pennylane)


if __name__ == "__main__":
    inputs = [(PI, PI / 2), (PI / 3, PI / 4), (PI / 5, PI / 6), (PI / 7, PI / 8)]
    dispatch_id = ct.dispatch(sweep_angles)(inputs)
    mean_squared_error = ct.get_result(dispatch_id, wait=True).result
    print(f"MSE: {mean_squared_error:.4f}")
